# %% [markdown]
# <a href="https://colab.research.google.com/github/hiddenkd/MIS-report/blob/main/OOP_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# • In Python everything is an object. Every function is an object, every variable is an object.
#
# • What is an object then ?
#
# • If you try to solve complex problems with conventional programming, your code will become too complex.
#
# • If everything is an object, where is their class ? Say L = [1,1,2,0 ] , this list variable L is an object belonging to list class.
#
# • OOP is a diff & easy way to code. It helps you to make customized data types. Say you want a data type to store a linkedin profile.
#
# • OOP → class → polymorphism → encapsulation → inheritance → abstraction

# %%
L = [1,1,2,55]
type(L)
# Out:
# list

# %% [markdown]
# • CLass is a blueprint telling how an object will behave.
#
# • Each class will have 2 stuffs.  DATA + FUNCTIONS
#
# • say for a class CAR , DATA will be color , no of wheels, plate no. FUNCTIONS will be calculate mileage, automatic braking system.

# %% [markdown]
# ◘ Name of class  to be in 'Pascle case' → People
#
# ◘ Name of variables and methods in snake case → tyre_size
#
# • Below is diagramatic view of a class. Whare + denotes a public stuff , and - denotes a private stuff

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# • Object is an instance of class

# %%
# @title  {"form-width":"1px","display-mode":"code"}
# to create object of a class

# waganar =Car()
# candidate = Applicant()
# langoor =Animal()

# %% [markdown]
# •  but then why do we, not use L = list(1,5,5,66)

# %%
L = [2,2,5,0,0,12]
M = list([2,2,5,0,0,12])
L,M
# Out:
# ([2, 2, 5, 0, 0, 12], [2, 2, 5, 0, 0, 12])

# %% [markdown]
# • Python allowed smaller case for built_in_class and their functions

# %%
# my_list = list()  # Built-in list class
# MyCustomList = MyList()  # User-defined class

# %% [markdown]
# * Functions inside a class are called Methods

# %%
len(L)  # this is a function , available to many data types.
L.append('a')  # this is a method, and this is just inside List class. Just for it's objects

# %%
class ATM:
# this is a constructor ( a method which is called automatically if we create object of this class)
  def __init__(self):     # can't use word other than __intit__
    print('Hello i am constructor')

  def menu(self):
    pass

# %%
a = ATM()
# Out:
# Hello i am constructor

# %%
class ATM():
  def __init__(self):
    print('Object created')
    self.pin = ''
    self.balance = 0
    self.start()

  def start(self):
    user_input = input("""
                          Hello , how would you like to proceed
                          Enter 1 for creating pin
                          Enter 2 for deposit
                          Enter 3 for withdraw
                          Enter 4 to check balance
                          Enter 5 to exit
    """)

# %%
Shivam = ATM()
# Out:
# Object created
#
#                           Hello , how would you like to proceed
#                           Enter 1 for creating pin
#                           Enter 2 for deposit
#                           Enter 3 for withdraw
#                           Enter 4 to check balance
#                           Enter 5 to exit
#     1

# %%
class ATM():
  def __init__(self):
    print('Object created')
    self.pin = ''
    self.balance = 0
    self.start()

  def start(self):
    user_input = input("""
                          Hello , how would you like to proceed
                          Enter 1 for creating pin
                          Enter 2 for deposit
                          Enter 3 for withdraw
                          Enter 4 to check balance
                          Enter 5 to exit
    """)
    if user_input =='1':
      print('Create Pin')
    elif user_input =='2':
      print('Deposit')
    elif user_input=='3':
      print('withdraw')
    elif user_input == 4:
      print('balance')
    else:
      print('exit')

# %%
Shivam = ATM()
# Out:
# Object created
#
#                           Hello , how would you like to proceed
#                           Enter 1 for creating pin
#                           Enter 2 for deposit
#                           Enter 3 for withdraw
#                           Enter 4 to check balance
#                           Enter 5 to exit
#     1
# Create Pin

# %%
class ATM():
  def __init__(self):
    print('Object created')
    self.pin = ''
    self.balance = 0
    self.start()

  def start(self):
    user_input = input("""
                          Hello , how would you like to proceed
                          Enter 1 for creating pin
                          Enter 2 for deposit
                          Enter 3 for withdraw
                          Enter 4 to check balance
                          Enter 5 to exit
    """)
    if user_input =='1':
      print('SELECTED -> Create Pin')
      self.create_pin()
    elif user_input =='2':
      print('SELECTED -> Deposit')
      self.deposit()
    elif user_input=='3':
      print('SELECTED -> withdraw')
      self.withdraw()
    elif user_input == 4:
      print('SELECTED ->balance')
      print(self.balance())
    else:
      print('SELECTED -> exit')

  def create_pin(self):
    temp = input('create a 4 digit pin')
    self.pin = temp
    print('pin crerated successfully')
  def deposit(self):
    temp = int(input('enter amount to be deposited'))
    self.balance = self.balance + temp
    print('successfully deposited')
  def withdraw(self):
    temp = (input('enter pin to access your money'))
    if self.pin == temp:
      amount = int(input('enter amount'))
      if amount <= self.balance:
        self.balance = self.balance - amount
      else:
        print(' insufficient balance')
    else:
      print('wrong pin')

# %%
Shivam=ATM()
# Out:
# Object created
#
#                           Hello , how would you like to proceed
#                           Enter 1 for creating pin
#                           Enter 2 for deposit
#                           Enter 3 for withdraw
#                           Enter 4 to check balance
#                           Enter 5 to exit
#     1
# SELECTED -> Create Pin
# create a 4 digit pin1234
# pin crerated successfully

# %%
Shivam.deposit()
# Out:
# enter amount to be deposited2000
# successfully deposited

# %%
Shivam.withdraw()
# Out:
# enter pin to access your money1234
# enter amount400

# %%
Shivam.balance
# Out:
# 1600

# %%
Shivam.pin           # well here we are able to access variables directly
# Out:
# '1234'

# %% [markdown]
# * There are a few magic methods , they afe of format '__ __xhgeyhd__ __'
#
# * They are pre-defined and can't be created by us
#
# * object(Shivam) can't generally calls these magic methods. They run automatically.

# %% [markdown]
# * What do we use constructor for ?
#
# * for giving default values , for running those methods , which you don't want user to run ( you don't rely on user )

# %% [markdown]
# * Now what is __self__
#
# * It is actually, you passing address of your object( variable )
#
# * You need to remember that only object can access methods of a class. Even one method cannot access another method, to do so , we need self again.
#
# * If we want to access a method inside another method, we use self.'name of method'  , and can't directly access method.

# %%
# Creating a custome data type

# %%
class Fraction :
  def __init__ ( self, n,d):
    print('inside constructor')
    self.num = n
    self.den = d
  def value(self):
    #return n/d
    return self.num /self.den

# %%
A = Fraction(2,3)
# Out:
# inside constructor

# %%
A.value()
# Out:
# 0.6666666666666666

# %%
print(A)

# %% [markdown]
# * well we haven't added a print method inside class , so python showed us nothing
#
# * if we use method __ __str__ __  inside class, this will get called automatically when we use __print()__ function
#
# * if we use method __ __add__ __  inside class, this will get called automatically when we use __A+B__ ( add two objects )
#
# * if we use method __ __sub__ __  inside class, this will get called automatically when we use __A-B__ ( add two objects )

# %%
class Fraction :
  def __init__ ( self, n,d):
    print('inside constructor')
    self.num = n
    self.den = d
  def value(self):
    #return n/d
    return self.num /self.den
  def __str__(self):
    return str(self.num) + '/' +str(self.den)
    # return '{}/{}'.format(self.num, self.den)
  def __add__(self,other):
    temp_num = self.num*other.den + other.num*self.den
    temp_den = self.den*other.den
    return '{}/{}'.format(temp_num, temp_den)
  def __sub__(self,other):
    temp_num = self.num*other.den - other.num*self.den
    temp_den = self.den*other.den
    return '{}/{}'.format(temp_num, temp_den)
  def __mul__(self,other):
    temp_num = self.num*other.num
    temp_den = self.den*other.den
    return '{}/{}'.format(temp_num, temp_den)
  def __truediv__(self,other):
    temp_num = self.num*other.den
    temp_den = self.den*other.num
    return '{}/{}'.format(temp_num, temp_den)

# %%
A = Fraction(2,3)
# Out:
# inside constructor

# %%
print(A)
# Out:
# 2/3

# %%
B = Fraction(1,3)
A+B
# Out:
# inside constructor
# '9/9'

# %%
A-B
# Out:
# '3/9'

# %%
A*B
# Out:
# '2/9'

# %%
A/B
# Out:
# '6/3'

# %% [markdown]
# * YOu can make your own class of say 2D geometry , matrices , lines , vectors , and allow user to perform any operations they like.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * __INstane Variable__  - these are varible inside a constructor , value for which is diff for each object. Like pin & balance will have diff value for diff person.

# %% [markdown]
# * How to hide variables and methods in a class ?
#
# * use '__' before them

# %%
class Fraction :
  def __init__ ( self, n,d):
    print('inside constructor')
    self.__num = n
    self.__den = d
  def __value(self):
    #return n/d
    return self.num /self.den

# %% [markdown]
# * doing so object can't access them directly say  A.sum = 5 ,
#
# * even A.__sum= 5 won't work
#
# * here python internally converts, __num to ' _ATM __sum'
#
# * NOTHING is TUELY PRIVATE .. means you can access it by using A._ATM__num

# %%
A = Fraction(2,3)
# Out:
# inside constructor

# %%
A._ATM__num =5

# %% [markdown]
# • Python is for matures, hence nothing is truely private
#
# * BUT you can , give user access to change these private variables ,  by , getter & setter
#
# * These will allow us to, change values of these private variables , with conditoins defined by us.

# %%
class ATM():
  def __init__(self):
    print('Object created')
    self.__pin = ''
    self.__balance = 0


  def get_pin(self):
    return self.__pin()
  def set_pin(self, new_pin):
    if type(new_pin) == str:
      self.__pin = new_pin
    else:
      print('not allowed')

# %% [markdown]
# * __ENCAPSULATION__ is hiding your variables and functions + allowing user to change them using , getter & setter

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * __Reference variable__
#
# * when we create an object using ATM() , we store it somewhere. like Aman = ATM()
#
# * if we don't store , then it will be lost
#
# * A is a variable that points to address where object ATM() is created.This means A is a reference variable.

# %%
# Lets see , how we can pass whole object as an argumet in a function
class Customer:
  def __init__(self, name, gender):
    self.name = name
    self.gender = gender

def greet(c):
  if c.gender == 'male':
    print('Hello', c.name , 'sir')
  else:
    print('Hello', c.name , 'maam')

# %%
A = Customer("Sheetal","female")

# %%
greet(A)    # you passes whole , object as an argument
# Out:
# Hello Sheetal maam

# %% [markdown]
# • __Aliasing__

# %%
a= 3
b = a
print(id(a))
print(id(b))
# Out:
# 140428645908784
# 140428645908784

# %% [markdown]
# • Both gives same address.

# %%
class Customer:
  def __init__(self, name):
    self.name = name

def greet(c):
  print(id(c))
A = Customer('aman')
print(id(A))
# Out:
# 140427324537248

# %%
greet(A)
# Out:
# 140427324537248

# %% [markdown]
# • Agar aapne ek function ko object paas kar diya, aur us ne object mai changes kar diye , to original object bhi change hoga , obvious hai.
#
# • Obviously obects of a class are mutable

# %%
# note all ID s are same
def change(L):
  print(id(L))
  L.append(5)
  print(id(L))

A = [1,5,55]
print(id(A))
change(A)
print(id(A))
print(A)
# Out:
# 140427318619264
# 140427318619264
# 140427318619264
# 140427318619264
# [1, 5, 55, 5]

# %% [markdown]
# • !!! this means never send original list into as function, as it can cause lots of problems, send a copy insted.

# %%
# note all ID s are same
def change(L):
  print(id(L))
  L.append(5)
  print(id(L))

A = [1,5,55]
print(id(A))
change(A[:]) ##
print(id(A))
print(A)
# Out:
# 140427317490432
# 140427317478144
# 140427317478144
# 140427317490432
# [1, 5, 55]

# %% [markdown]
# • But if you are using a Tuple, then no problem with it
#
# • in pass by reference , if you send a mutable data type, then it can get changed , so send it's copy , bUT using an immutable data type brings no issues.

# %%
# we can have a list of objects
class Customer:
  def __init__(self, name, age):
    self.name = name
    self.age = age
  def intro(self):
    print('I am ', self.name,'and i am ', self.age, 'yrs old')

c1 = Customer('Nitish', 34)
c2 = Customer('Shivam', 34)
c3 = Customer('Garuna', 34)

L=[c1,c2,c3]

for i in L:
  print(i.name, i.age)

for i in L:
  i.intro()
# Out:
# Nitish 34
# Shivam 34
# Garuna 34
# I am  Nitish and i am  34 yrs old
# I am  Shivam and i am  34 yrs old
# I am  Garuna and i am  34 yrs old

# %% [markdown]
# • Instance variable = value is diff for each object
#
# • class / static variable = value is same for all objects [ styatic are defined oputside constructor ]

# %%
# we can have a list of objects
class Customer:
  counter = 1

  def __init__(self, name, age):
    self.name = name
    self.age = age
    self.sno = Customer.counter
    Customer.counter +=1

c1 = Customer('Nitish', 34)
c2 = Customer('Shivam', 34)
c3 = Customer('Garuna', 34)

L=[c1,c2,c3]

for i in L:
  print(i.name, i.age , i.sno)
Customer.counter , c1.sno , c1.counter  # c1 can access that counter
# Out:
# Nitish 34 1
# Shivam 34 2
# Garuna 34 3
# (4, 1, 4)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# • just trying to make counter private, and have getter & setter
#
# • A mistake he did was, sef.sno = Atm.__counter
#
# • another mistake done is Atm.__Counter = new
#
# ◘ XX ... (self) is not needed , in get_counter() & set_counter()
#
# ◘ these methods which do not need, self are called static methods

# %% [markdown]
# • hence static method is a method which can be accessed without object
#
# • generally it deals with static variables

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# • car is a vehicle  ,  smartphone is a product
#
# • address has a customer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# • add in Customer('Nitish','male',add) .. is object itself , created above

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# • WoW such a complex code

# %%
def change(a=5,b=6):
  print(a+b)
change(3,)
change()
change(1)
# change(,2)
change(b=50)
# Out:
# 9
# 11
# 7
# 55

# %%
help(change) # this gives info about change functions
# Out:
# Help on function change in module __main__:
#
# change(a=5, b=6)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * instead of dry coding, i will user inheritance , to write code for login and registration only once. And Student and instructor classes will inherit form user class.
#
# * so, inheritance gives code re_usability

# %% [markdown]
# * So what we inherit ?
#
# * we inherit data memnbers / member functions / constructor
#
# * we don't inherit private members

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * I guess i forgot to show class diagram for aggregation (DIAMOND)
#
# * for inheritance is is arrow

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * if child class does not have a constructor,  constructor of parent class will be called

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * this code will crash , as __brand is a hidden variable and this can't be inherited

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * __Method overriding__  this means if methods of same name are present in panret and child , then method of child wil be called and not that of parent/
#
# * both overloading will be discussed later

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * __"Buying a smartphone"__

# %% [markdown]
# * So, how can child access private methods / variable ?
#
# * Make a public method that gives access to private varaible

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * __get_num__ helps you access private variable

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * This gives __error__ as instructor of parent was never called ( child has it's own constructor), hence __get_num__ will have no value of ____num__ to show

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * __100__ as __diaplay1__ called var1 = local variable of that class not that of child

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * __super()__ keyword is used to access parent class method having a common name with child class
#
# * note __super()__ is not needed if names of mathods are different

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * __super()__ won't work outside child class.
#
# * hence in any question where __super()__ is used outside will be an error

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Here i am calling constructor of parent class usiong __super()__  to store common variables, and i later store specific variable in child class

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * __super()__ has to be 1st sentence inside chid's constructor

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Yes this will work, as self is address of son = child()
#
# * note here without passing anything __son = Child()__ they are assigning vales to variables __num & var__

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 4 types of inheritance,  5th one is hybrid = combination of these 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# * another way to directly create object and use a function , no need to create a variable in b/w

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Whose, constructor will be called 1st ?
#
# * Phone
#
# * if both have a method with same name ,then Phone's method will be called
#
# * MRO = method resolutoin order

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Polymorphism = Multiple phases

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# • Method over_riding means , if you use methods with same name, Which one will be called. Method overwriding means as per no of arguments passed, one whch has same no of methods, it will be called.

# %% [markdown]
# • If you pass 1 argument, R^2 area will be called,
#
# • if you pass 2 arguments L*B will be called.

# %% [markdown]
# ◘ BUT in python , only 2nd code will run, hence in Python method overloading does not works.
#
# • BUT you can get it done as follows.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# • __defenition__ of __method overtloading__ → it is differenty behaviour of a merthod by passing different inputs.

# %% [markdown]
# • __Operator Overtloading__ this means , telling a normal operator to do something different , like 'sdfsf'+'sdfsf'= 'sdfsfsdfsf'
#
# • here + used to add numbers is doing diff stuff, this was already programmed in string class
